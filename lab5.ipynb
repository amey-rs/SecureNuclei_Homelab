# %%
import networkx as nx
import matplotlib.pyplot as plt

# Generate a random graph
G = nx.gnp_random_graph(10, p=0.3)

# Draw the graph
nx.draw(G, with_labels=True, font_weight='bold', node_color='skyblue', edge_color='gray')

# Display the graph
plt.show()
